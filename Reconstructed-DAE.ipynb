# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, confusion_matrix
from torch.utils.data import SubsetRandomSampler, DataLoader
import matplotlib.pyplot as plt

# %%
import numpy as np
import torch
import torch.nn as nn
from data_processing import get_data


DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(DEVICE)
# Out:
# cuda:0

# %%
print(torch.cuda.device_count())
print(torch.cuda.current_device())
print(torch.cuda.get_device_name(0))
# Out:
# 1
# 0
# NVIDIA GeForce GTX 1050 Ti

# %%
DATASET_NAME = "sherbrooke"

# %%
normal_data, abnormal_data, real_abnormal_data, real_abnormal_data_2 = get_data(DATASET_NAME)
# Out:
# Normal data shape: (20606, 125)
# Abnormal data shape: (186, 125)
# Real abnormal data shape: (406, 125)
# Real abnormal data 2 shape: (406, 125)

# %%
# Transform torch tensors to keras tensors
normal_data = torch.Tensor(normal_data)
abnormal_data = torch.Tensor(abnormal_data)
real_abnormal_data = torch.Tensor(real_abnormal_data)
real_abnormal_data_2 = torch.Tensor(real_abnormal_data_2)

# %%
train_data = normal_data
test_data = torch.concat([abnormal_data, real_abnormal_data, real_abnormal_data_2])
print(train_data.shape)
print(test_data.shape)
# Out:
# torch.Size([20606, 125])
# torch.Size([998, 125])

# %%
# Define the DAE
class DAE(nn.Module):
    def __init__(self,
                 input_size,
                 hidden_layers=(16,),
                 hidden_activation=nn.ReLU,
                 output_activation=nn.Sigmoid
                 ):
        super(DAE, self).__init__()
        self.input_size = input_size
        self.hidden_layers = hidden_layers
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation

        # Add the encoding layers
        self.encoded = self.create_layers(hidden_layers, input_size)

        # Add the decoding layers with the output activation function
        self.decoded = self.create_layers(hidden_layers[-2::-1], hidden_layers[-1])
        self.decoded.append(nn.Linear(hidden_layers[0], input_size))
        self.decoded.append(self.output_activation())

    def create_layers(self, design, input_size):
        layers = []
        for i, layer in enumerate(design):
            in_features = design[i-1] if i > 0 else input_size
            out_features = layer
            layers.append(nn.Linear(in_features, out_features))
            layers.append(self.hidden_activation())

        return nn.Sequential(*layers)

    def forward(self, input):
        encoded = self.encoded(input)
        # print(self.decoded)
        decoded = self.decoded(encoded)
        return decoded

# %%
# Define hyperparameters
BATCH_SIZE = 128
EPOCHS = 10
criterion = nn.MSELoss()
hidden_layers = (128,64,32,16,8)
learning_rate = 0.001

# Create the KFold object for cross validation
folds = 10
splits = KFold(n_splits=folds, shuffle=True, random_state=42)

# %%
# Define the model
model = DAE(input_size=train_data.shape[1], hidden_layers=hidden_layers).to(DEVICE)
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate)

# %%
### Get initial results on abnormal data before testing
model = model.cpu()
with torch.no_grad():
    # Compute a placeholder threshold
    output = model(train_data)
    assert output.shape == train_data.shape, "The predicted data shape is not right!"
    mse_per_sample = [mean_squared_error(train_data[i], output[i]) for i in range(output.shape[0])]
    normal_score = np.mean(mse_per_sample)
    threshold = normal_score + normal_score + 3 * (np.std(mse_per_sample) + np.std(mse_per_sample))

    # Test the abnormal data with the placeholder threshold
    output = model(test_data)
    mse_per_sample = [mean_squared_error(test_data[i], output[i]) for i in range(output.shape[0])]
    abnormal_test_ratio = sum([score > threshold for score in mse_per_sample])/float(len(mse_per_sample))
    print(f"Abnormal ratio: {abnormal_test_ratio}")
model = model.to(DEVICE)
# Out:
# Abnormal ratio: 0.0

# %%
print("Training the deep autoencoder")

history = {
    'train_score': [],
    'val_score': [],
    'train_loss': [],
    'val_loss': [],
    'threshold': [],
    'abnormal_ratio': [],
    'normal_train_ratio': [],
    'normal_valid_ratio': []
}

for fold, (train_idx, val_idx) in enumerate(splits.split(train_data)):
    print(f"Fold {fold+1}")
    train_sampler = SubsetRandomSampler(train_idx)
    validation_sampler = SubsetRandomSampler(val_idx)
    train_dataloader = DataLoader(train_data, batch_size=BATCH_SIZE, sampler=train_sampler)
    validation_dataloader = DataLoader(train_data, batch_size=BATCH_SIZE, sampler=validation_sampler)

    # Train the model on the scaled data
    for epoch in range(EPOCHS):
        total_train_loss = 0
        total_validation_loss = 0
        print(f"Epoch {epoch}")
        for i, trajectories in enumerate(train_dataloader):
            trajectories = trajectories.to(DEVICE, dtype=torch.float32)
            # print(type(trajectories[0]))

            # Forward pass
            model.zero_grad()
            output = model(trajectories)
            loss = criterion(output, trajectories)
            total_train_loss += loss / len(train_dataloader)

            # Backward pass
            loss.backward()
            optimizer.step()

        history['train_loss'].append(total_train_loss.cpu())

        # Evaluate model at this epoch
        model.eval()
        model = model.cpu()
        with torch.no_grad():
            # Get the training score
            mse_per_sample_train = []
            for i, trajectories in enumerate(train_dataloader):
                output = model(trajectories)
                assert output.shape == trajectories.shape, "The predicted data shape is not right!"
                mse_per_sample_train.extend([mean_squared_error(trajectories[i], output[i]) for i in range(output.shape[0])])
            train_score = np.mean(mse_per_sample_train)
            print(f"Train score: {train_score}")
            history['train_score'].append(train_score)

            # Get validation score
            mse_per_sample_validation = []
            for i, trajectories in enumerate(validation_dataloader):
                output = model(trajectories)
                assert output.shape == trajectories.shape, "The predicted data shape is not right!"
                mse_per_sample_validation.extend([mean_squared_error(trajectories[i], output[i]) for i in range(output.shape[0])])

                # Also get loss for rating model
                loss = criterion(output, trajectories)
                total_validation_loss += loss / len(validation_dataloader)
            validation_score = np.mean(mse_per_sample_validation)
            print(f"Validation score: {validation_score}")
            history['val_score'].append(validation_score)
            history['val_loss'].append(total_validation_loss)

            # Calculate threshold
            threshold = train_score + validation_score + 3 * (np.std(mse_per_sample_train) + np.std(mse_per_sample_validation))
            print(f"Threshold value: {threshold}")
            history['threshold'].append(threshold)

            normal_train_ratio = sum([score < threshold for score in mse_per_sample_train])/float(len(mse_per_sample_train))
            print(f"Normal train ratio: {normal_train_ratio * 100}%")
            normal_valid_ratio = sum([score < threshold for score in mse_per_sample_validation])/float(len(mse_per_sample_validation))
            print(f"Normal validation ratio: {normal_valid_ratio * 100}%")
            history['normal_train_ratio'].append(normal_train_ratio)
            history['normal_valid_ratio'].append(normal_valid_ratio)

            # Get the ratio of correctly labeled abnormal data
            predicted_test_data = model(test_data)
            assert predicted_test_data.shape == test_data.shape, "The predicted data shape is not right!"
            mse_per_sample = [mean_squared_error(test_data[i], predicted_test_data[i]) for i in range(test_data.shape[0])]

            abnormal_test_ratio = sum([score > threshold for score in mse_per_sample])/float(len(mse_per_sample))
            print(f"Abnormal ratio: {abnormal_test_ratio * 100}%")
            history['abnormal_ratio'].append(abnormal_test_ratio)
        model = model.to(DEVICE)
        model.train()
# Out:
# Training the deep autoencoder
# Fold 1
# Epoch 0
# Train score: 0.010562310926616192
# Validation score: 0.010821215808391571
# Threshold value: 0.10742458514869213
# Normal train ratio: 99.71420868158533%
# Normal validation ratio: 99.61183891314896%
# Abnormal ratio: 12.925851703406813%
# Epoch 1
# Train score: 0.005362629424780607
# Validation score: 0.005382094532251358
# Threshold value: 0.041571774519979954
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 14.729458917835672%
# Epoch 2
# Train score: 0.005483502056449652
# Validation score: 0.005416207481175661
# Threshold value: 0.04459316376596689
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 23.146292585170343%
# Epoch 3
# Train score: 0.0029707220382988453
# Validation score: 0.0029707388021051884
# Threshold value: 0.024109139572829008
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 49.298597194388776%
# Epoch 4
# Train score: 0.002539183711633086
# Validation score: 0.0025332379154860973
# Threshold value: 0.022945793345570564
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 52.00400801603207%
# Epoch 5
# Train score: 0.0032902704551815987
# Validation score: 0.003227855544537306
# Threshold value: 0.027359370607882738
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 40.78156312625251%
# Epoch 6
# Train score: 0.0036245782393962145
# Validation score: 0.0036186857614666224
# Threshold value: 0.03261778550222516
# Normal train ratio: 99.77352386087894%
# Normal validation ratio: 99.56331877729258%
# Abnormal ratio: 25.35070140280561%
# Epoch 7
# Train score: 0.001968089956790209
# Validation score: 0.001959008164703846
# Threshold value: 0.01835228083655238
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 57.71543086172345%
# Epoch 8
# Train score: 0.0018246930558234453
# Validation score: 0.0018168414244428277
# Threshold value: 0.017214770894497633
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 67.13426853707415%
# Epoch 9
# Train score: 0.0023374189622700214
# Validation score: 0.002340413862839341
# Threshold value: 0.019026209600269794
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 58.21643286573146%
# Fold 2
# Epoch 0
# Train score: 0.0019028022652491927
# Validation score: 0.0019052659627050161
# Threshold value: 0.01863590069115162
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 63.827655310621246%
# Epoch 1
# Train score: 0.0017333755968138576
# Validation score: 0.0017153375083580613
# Threshold value: 0.01760375965386629
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 65.23046092184369%
# Epoch 2
# Train score: 0.0014012206811457872
# Validation score: 0.001380953355692327
# Threshold value: 0.014590020757168531
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 75.75150300601202%
# Epoch 3
# Train score: 0.0017993722576647997
# Validation score: 0.001780846854671836
# Threshold value: 0.017271440476179123
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 69.13827655310621%
# Epoch 4
# Train score: 0.0013611777685582638
# Validation score: 0.0013489482225850224
# Threshold value: 0.014181464444845915
# Normal train ratio: 99.98921542194662%
# Normal validation ratio: 99.95147986414362%
# Abnormal ratio: 79.15831663326654%
# Epoch 5
# Train score: 0.001340745948255062
# Validation score: 0.0013217271771281958
# Threshold value: 0.013935568509623408
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 79.15831663326654%
# Epoch 6
# Train score: 0.0019983178935945034
# Validation score: 0.0020264338236302137
# Threshold value: 0.019387880340218544
# Normal train ratio: 99.96225397681316%
# Normal validation ratio: 99.95147986414362%
# Abnormal ratio: 65.03006012024048%
# Epoch 7
# Train score: 0.0013049440458416939
# Validation score: 0.0012828540056943893
# Threshold value: 0.012807539664208889
# Normal train ratio: 99.82205446211917%
# Normal validation ratio: 99.85443959243085%
# Abnormal ratio: 82.86573146292585%
# Epoch 8
# Train score: 0.0027491548098623753
# Validation score: 0.0026817023754119873
# Threshold value: 0.023719162680208683
# Normal train ratio: 99.98382313291992%
# Normal validation ratio: 100.0%
# Abnormal ratio: 56.4128256513026%
# Epoch 9
# Train score: 0.0012967917136847973
# Validation score: 0.0012856153771281242
# Threshold value: 0.011418997775763273
# Normal train ratio: 99.81666217309247%
# Normal validation ratio: 99.80591945657447%
# Abnormal ratio: 84.86973947895791%
# Fold 3
# Epoch 0
# Train score: 0.0018927577184513211
# Validation score: 0.0018454368691891432
# Threshold value: 0.012760219629853964
# Normal train ratio: 99.98921542194662%
# Normal validation ratio: 100.0%
# Abnormal ratio: 84.16833667334669%
# Epoch 1
# Train score: 0.0015775756910443306
# Validation score: 0.0015277205966413021
# Threshold value: 0.011861301958560944
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 82.46492985971943%
# Epoch 2
# Train score: 0.0009708114666864276
# Validation score: 0.0009442343143746257
# Threshold value: 0.009150866884738207
# Normal train ratio: 99.96764626583985%
# Normal validation ratio: 100.0%
# Abnormal ratio: 89.27855711422845%
# Epoch 3
# Train score: 0.0014097447274252772
# Validation score: 0.0013875424629077315
# Threshold value: 0.010024275863543153
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 86.97394789579158%
# Epoch 4
# Train score: 0.0012462955201044679
# Validation score: 0.001237891148775816
# Threshold value: 0.010758454212918878
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 86.27254509018036%
# Epoch 5
# Train score: 0.0009051556698977947
# Validation score: 0.0008837765781208873
# Threshold value: 0.008401047554798424
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 90.8817635270541%
# Epoch 6
# Train score: 0.0009166121017187834
# Validation score: 0.0008943412685766816
# Threshold value: 0.008405018947087228
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 89.87975951903807%
# Epoch 7
# Train score: 0.0011733603896573186
# Validation score: 0.001153019373305142
# Threshold value: 0.009439391316846013
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.47695390781564%
# Epoch 8
# Train score: 0.0010560748632997274
# Validation score: 0.00103617028798908
# Threshold value: 0.008873686660081148
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 87.7755511022044%
# Epoch 9
# Train score: 0.0009291221504099667
# Validation score: 0.0009075924172066152
# Threshold value: 0.008488597813993692
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 89.87975951903807%
# Fold 4
# Epoch 0
# Train score: 0.0008760634809732437
# Validation score: 0.0008546756580471992
# Threshold value: 0.008182755205780268
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 89.47895791583166%
# Epoch 1
# Train score: 0.0008859955705702305
# Validation score: 0.0008663767366670072
# Threshold value: 0.008196343202143908
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.77755511022045%
# Epoch 2
# Train score: 0.0009694854961708188
# Validation score: 0.0009513658005744219
# Threshold value: 0.008516949485056102
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.67735470941884%
# Epoch 3
# Train score: 0.0008917090017348528
# Validation score: 0.0008718457538634539
# Threshold value: 0.00828424165956676
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 89.37875751503006%
# Epoch 4
# Train score: 0.0008924255380406976
# Validation score: 0.0008722087950445712
# Threshold value: 0.00823302031494677
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 87.4749498997996%
# Epoch 5
# Train score: 0.0009192513534799218
# Validation score: 0.000896635465323925
# Threshold value: 0.008322973386384547
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.67735470941884%
# Epoch 6
# Train score: 0.0009753488702699542
# Validation score: 0.0009588755201548338
# Threshold value: 0.008683677879162133
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 87.4749498997996%
# Epoch 7
# Train score: 0.0009208949632011354
# Validation score: 0.0009031396475620568
# Threshold value: 0.00813912390731275
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.07615230460922%
# Epoch 8
# Train score: 0.0008543089497834444
# Validation score: 0.0008371496223844588
# Threshold value: 0.007979182293638587
# Normal train ratio: 99.98921542194662%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.67735470941884%
# Epoch 9
# Train score: 0.0011482755653560162
# Validation score: 0.0011349021224305034
# Threshold value: 0.00937485322356224
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 84.16833667334669%
# Fold 5
# Epoch 0
# Train score: 0.001028651837259531
# Validation score: 0.0010198646923527122
# Threshold value: 0.008967705070972443
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 86.37274549098196%
# Epoch 1
# Train score: 0.0008328324183821678
# Validation score: 0.0008265578653663397
# Threshold value: 0.007842629449442029
# Normal train ratio: 99.98921542194662%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.77755511022045%
# Epoch 2
# Train score: 0.0008334899903275073
# Validation score: 0.0008275615400634706
# Threshold value: 0.007879307493567467
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.17635270541082%
# Epoch 3
# Train score: 0.0008417231729254127
# Validation score: 0.0008370470022782683
# Threshold value: 0.007869688561186194
# Normal train ratio: 99.98921542194662%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.57715430861724%
# Epoch 4
# Train score: 0.000830190081615001
# Validation score: 0.000825725554022938
# Threshold value: 0.00785467668902129
# Normal train ratio: 99.98921542194662%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.47695390781564%
# Epoch 5
# Train score: 0.0008308335673063993
# Validation score: 0.0008245298522524536
# Threshold value: 0.007888192776590586
# Normal train ratio: 99.98921542194662%
# Normal validation ratio: 100.0%
# Abnormal ratio: 87.97595190380761%
# Epoch 6
# Train score: 0.0008242416079156101
# Validation score: 0.0008197322604246438
# Threshold value: 0.007818963844329119
# Normal train ratio: 99.98921542194662%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.07615230460922%
# Epoch 7
# Train score: 0.0009344143909402192
# Validation score: 0.000928421737626195
# Threshold value: 0.00836374657228589
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 87.97595190380761%
# Epoch 8
# Train score: 0.0008454269263893366
# Validation score: 0.0008389684953726828
# Threshold value: 0.007838282501325011
# Normal train ratio: 99.98921542194662%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.77755511022045%
# Epoch 9
# Train score: 0.0010868472745642066
# Validation score: 0.0010856868466362357
# Threshold value: 0.009142050286754966
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 86.07214428857716%
# Fold 6
# Epoch 0
# Train score: 0.0008417515782639384
# Validation score: 0.0008891003672033548
# Threshold value: 0.0081506542628631
# Normal train ratio: 99.98921542194662%
# Normal validation ratio: 99.95147986414362%
# Abnormal ratio: 88.17635270541082%
# Epoch 1
# Train score: 0.0008705084910616279
# Validation score: 0.0009202342480421066
# Threshold value: 0.008187892264686525
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 87.5751503006012%
# Epoch 2
# Train score: 0.0008664277847856283
# Validation score: 0.0009150530677288771
# Threshold value: 0.008079007267951965
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 89.27855711422845%
# Epoch 3
# Train score: 0.0008415232878178358
# Validation score: 0.0008905790164135396
# Threshold value: 0.007991970283910632
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 87.7755511022044%
# Epoch 4
# Train score: 0.0008365813409909606
# Validation score: 0.0008861232199706137
# Threshold value: 0.007980558089911938
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 89.27855711422845%
# Epoch 5
# Train score: 0.000900736718904227
# Validation score: 0.0009458443964831531
# Threshold value: 0.008413958712480962
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 87.4749498997996%
# Epoch 6
# Train score: 0.0009411972132511437
# Validation score: 0.0009907196508720517
# Threshold value: 0.008536975365132093
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.27655310621243%
# Epoch 7
# Train score: 0.0007911234279163182
# Validation score: 0.0008393126772716641
# Threshold value: 0.0077537125907838345
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 100.0%
# Abnormal ratio: 89.27855711422845%
# Epoch 8
# Train score: 0.0008585283649154007
# Validation score: 0.0009058667928911746
# Threshold value: 0.007933949469588697
# Normal train ratio: 99.98921542194662%
# Normal validation ratio: 99.95147986414362%
# Abnormal ratio: 89.67935871743487%
# Epoch 9
# Train score: 0.0007909380947239697
# Validation score: 0.0008396152989007533
# Threshold value: 0.0077504770597442985
# Normal train ratio: 99.9946077109733%
# Normal validation ratio: 99.95147986414362%
# Abnormal ratio: 89.97995991983969%
# Fold 7
# Epoch 0
# Train score: 0.0008077114471234381
# Validation score: 0.000815597886685282
# Threshold value: 0.007718261913396418
# Normal train ratio: 99.99460800172544%
# Normal validation ratio: 100.0%
# Abnormal ratio: 91.28256513026052%
# Epoch 1
# Train score: 0.0008123380248434842
# Validation score: 0.0008213763940148056
# Threshold value: 0.007712343242019415
# Normal train ratio: 99.98921600345088%
# Normal validation ratio: 99.9514563106796%
# Abnormal ratio: 90.78156312625251%
# Epoch 2
# Train score: 0.002946416847407818
# Validation score: 0.002910011913627386
# Threshold value: 0.0314137008972466
# Normal train ratio: 99.85980804486144%
# Normal validation ratio: 99.90291262135922%
# Abnormal ratio: 33.26653306613226%
# Epoch 3
# Train score: 0.0007868723478168249
# Validation score: 0.0007960401708260179
# Threshold value: 0.0076649332186207175
# Normal train ratio: 99.98382400517632%
# Normal validation ratio: 100.0%
# Abnormal ratio: 90.6813627254509%
# Epoch 4
# Train score: 0.0008433812181465328
# Validation score: 0.0008548295008949935
# Threshold value: 0.007867524051107466
# Normal train ratio: 99.99460800172544%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.97795591182364%
# Epoch 5
# Train score: 0.0007849048124626279
# Validation score: 0.0007946810219436884
# Threshold value: 0.007623473065905273
# Normal train ratio: 99.99460800172544%
# Normal validation ratio: 100.0%
# Abnormal ratio: 92.08416833667334%
# Epoch 6
# Train score: 0.000914853299036622
# Validation score: 0.0009258431382477283
# Threshold value: 0.00844397721812129
# Normal train ratio: 99.99460800172544%
# Normal validation ratio: 100.0%
# Abnormal ratio: 90.18036072144288%
# Epoch 7
# Train score: 0.0009812803473323584
# Validation score: 0.0009915943956002593
# Threshold value: 0.00853538722731173
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 89.47895791583166%
# Epoch 8
# Train score: 0.0007939067436382174
# Validation score: 0.0008050483302213252
# Threshold value: 0.007687091827392578
# Normal train ratio: 99.98921600345088%
# Normal validation ratio: 99.9514563106796%
# Abnormal ratio: 90.8817635270541%
# Epoch 9
# Train score: 0.0009241183288395405
# Validation score: 0.0009339905227534473
# Threshold value: 0.008462934754788876
# Normal train ratio: 99.99460800172544%
# Normal validation ratio: 100.0%
# Abnormal ratio: 92.68537074148297%
# Fold 8
# Epoch 0
# Train score: 0.0008871729951351881
# Validation score: 0.0008789481362327933
# Threshold value: 0.008045132621191442
# Normal train ratio: 99.99460800172544%
# Normal validation ratio: 100.0%
# Abnormal ratio: 92.28456913827655%
# Epoch 1
# Train score: 0.0007872297428548336
# Validation score: 0.0007793715922161937
# Threshold value: 0.007556254859082401
# Normal train ratio: 99.98921600345088%
# Normal validation ratio: 99.9514563106796%
# Abnormal ratio: 92.38476953907816%
# Epoch 2
# Train score: 0.0008581326110288501
# Validation score: 0.0008465007413178682
# Threshold value: 0.007782052387483418
# Normal train ratio: 99.99460800172544%
# Normal validation ratio: 99.9514563106796%
# Abnormal ratio: 90.98196392785572%
# Epoch 3
# Train score: 0.0008577366243116558
# Validation score: 0.0008480286924168468
# Threshold value: 0.007878233678638935
# Normal train ratio: 99.99460800172544%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.87775551102204%
# Epoch 4
# Train score: 0.0007949656574055552
# Validation score: 0.0007859746110625565
# Threshold value: 0.007556067313998938
# Normal train ratio: 99.98382400517632%
# Normal validation ratio: 99.9514563106796%
# Abnormal ratio: 92.78557114228457%
# Epoch 5
# Train score: 0.0007741298759356141
# Validation score: 0.0007676960085518658
# Threshold value: 0.00748182088136673
# Normal train ratio: 99.98921600345088%
# Normal validation ratio: 99.9514563106796%
# Abnormal ratio: 92.18436873747495%
# Epoch 6
# Train score: 0.0008365996764041483
# Validation score: 0.0008305097580887377
# Threshold value: 0.007724699680693448
# Normal train ratio: 99.99460800172544%
# Normal validation ratio: 99.9514563106796%
# Abnormal ratio: 94.0881763527054%
# Epoch 7
# Train score: 0.0008693566778674722
# Validation score: 0.0008558086701668799
# Threshold value: 0.007850120309740305
# Normal train ratio: 99.99460800172544%
# Normal validation ratio: 100.0%
# Abnormal ratio: 90.38076152304609%
# Epoch 8
# Train score: 0.0008527409518137574
# Validation score: 0.0008447504951618612
# Threshold value: 0.007743107387796044
# Normal train ratio: 99.99460800172544%
# Normal validation ratio: 99.9514563106796%
# Abnormal ratio: 90.98196392785572%
# Epoch 9
# Train score: 0.0007658267859369516
# Validation score: 0.0007600904791615903
# Threshold value: 0.007431591162458062
# Normal train ratio: 99.98921600345088%
# Normal validation ratio: 99.9514563106796%
# Abnormal ratio: 92.68537074148297%
# Fold 9
# Epoch 0
# Train score: 0.001510749338194728
# Validation score: 0.0015501207672059536
# Threshold value: 0.013002347899600863
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 81.86372745490982%
# Epoch 1
# Train score: 0.0011070125037804246
# Validation score: 0.0011524101719260216
# Threshold value: 0.00970702851191163
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 84.16833667334669%
# Epoch 2
# Train score: 0.0007690167403779924
# Validation score: 0.0008050528704188764
# Threshold value: 0.007515784236602485
# Normal train ratio: 99.98382400517632%
# Normal validation ratio: 100.0%
# Abnormal ratio: 91.78356713426854%
# Epoch 3
# Train score: 0.0007992353057488799
# Validation score: 0.0008370309951715171
# Threshold value: 0.007668826729059219
# Normal train ratio: 99.98921600345088%
# Normal validation ratio: 100.0%
# Abnormal ratio: 91.18236472945893%
# Epoch 4
# Train score: 0.0007951882435008883
# Validation score: 0.0008324609370902181
# Threshold value: 0.00759267108514905
# Normal train ratio: 99.98921600345088%
# Normal validation ratio: 100.0%
# Abnormal ratio: 91.28256513026052%
# Epoch 5
# Train score: 0.0007766322232782841
# Validation score: 0.0008151030051521957
# Threshold value: 0.00753272557631135
# Normal train ratio: 99.98921600345088%
# Normal validation ratio: 100.0%
# Abnormal ratio: 91.88376753507013%
# Epoch 6
# Train score: 0.0007904664380475879
# Validation score: 0.0008295146399177611
# Threshold value: 0.007589252665638924
# Normal train ratio: 99.98921600345088%
# Normal validation ratio: 100.0%
# Abnormal ratio: 90.48096192384769%
# Epoch 7
# Train score: 0.0008707722299732268
# Validation score: 0.0009056460694409907
# Threshold value: 0.007913544424809515
# Normal train ratio: 99.99460800172544%
# Normal validation ratio: 100.0%
# Abnormal ratio: 92.88577154308616%
# Epoch 8
# Train score: 0.0008538629626855254
# Validation score: 0.000897559046279639
# Threshold value: 0.008185233222320676
# Normal train ratio: 99.97843200690177%
# Normal validation ratio: 100.0%
# Abnormal ratio: 89.37875751503006%
# Epoch 9
# Train score: 0.000953923212364316
# Validation score: 0.000992559944279492
# Threshold value: 0.008650488569401205
# Normal train ratio: 99.99460800172544%
# Normal validation ratio: 100.0%
# Abnormal ratio: 88.57715430861724%
# Fold 10
# Epoch 0
# Train score: 0.0007773975958116353
# Validation score: 0.0007745170150883496
# Threshold value: 0.007360448827967048
# Normal train ratio: 99.97843200690177%
# Normal validation ratio: 100.0%
# Abnormal ratio: 91.38276553106212%
# Epoch 1
# Train score: 0.0007897052564658225
# Validation score: 0.0007892022840678692
# Threshold value: 0.00749100954271853
# Normal train ratio: 99.98921600345088%
# Normal validation ratio: 100.0%
# Abnormal ratio: 92.68537074148297%
# Epoch 2
# Train score: 0.0007765591144561768
# Validation score: 0.000776293221861124
# Threshold value: 0.0073733527678996325
# Normal train ratio: 99.97843200690177%
# Normal validation ratio: 100.0%
# Abnormal ratio: 92.78557114228457%
# Epoch 3
# Train score: 0.0007652797503396869
# Validation score: 0.0007653915672563016
# Threshold value: 0.007361113326624036
# Normal train ratio: 99.97843200690177%
# Normal validation ratio: 100.0%
# Abnormal ratio: 92.08416833667334%
# Epoch 4
# Train score: 0.0007665288867428899
# Validation score: 0.0007671085768379271
# Threshold value: 0.007378433598205447
# Normal train ratio: 99.97843200690177%
# Normal validation ratio: 100.0%
# Abnormal ratio: 92.48496993987976%
# Epoch 5
# Train score: 0.0008681273902766407
# Validation score: 0.0008669391390867531
# Threshold value: 0.007726013660430908
# Normal train ratio: 99.98921600345088%
# Normal validation ratio: 100.0%
# Abnormal ratio: 90.8817635270541%
# Epoch 6
# Train score: 0.0007801813189871609
# Validation score: 0.0007797589641995728
# Threshold value: 0.007350353174842894
# Normal train ratio: 99.98382400517632%
# Normal validation ratio: 100.0%
# Abnormal ratio: 93.28657314629258%
# Epoch 7
# Train score: 0.0007719783461652696
# Validation score: 0.0007711478974670172
# Threshold value: 0.007382002309896052
# Normal train ratio: 99.98382400517632%
# Normal validation ratio: 100.0%
# Abnormal ratio: 91.38276553106212%
# Epoch 8
# Train score: 0.0008198224240913987
# Validation score: 0.0008213540422730148
# Threshold value: 0.007572070695459843
# Normal train ratio: 99.99460800172544%
# Normal validation ratio: 100.0%
# Abnormal ratio: 93.18637274549098%
# Epoch 9
# Train score: 0.0007739596767351031
# Validation score: 0.0007730895304121077
# Threshold value: 0.007408275967463851
# Normal train ratio: 99.98382400517632%
# Normal validation ratio: 100.0%
# Abnormal ratio: 93.28657314629258%

# %%
print(threshold)
# Out:
# 0.007408275967463851

# %%
model = model.cpu()
model.eval()
# Out:
# DAE(
#   (encoded): Sequential(
#     (0): Linear(in_features=125, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=32, out_features=16, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=16, out_features=8, bias=True)
#     (9): ReLU()
#   )
#   (decoded): Sequential(
#     (0): Linear(in_features=8, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=128, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=125, bias=True)
#     (9): Sigmoid()
#   )
# )

# %%
# Test model on normal data
with torch.no_grad():
    output = model(train_data)
    assert output.shape == train_data.shape, "The predicted data shape is not right!"
    mse_per_sample = [mean_squared_error(train_data[i], output[i]) for i in range(train_data.shape[0])]

    normal_test_ratio = sum([score < threshold for score in mse_per_sample])/float(len(mse_per_sample))
    tp = len([score for score in mse_per_sample if score < threshold])
    fn = len([score for score in mse_per_sample if score >= threshold])
    print(f"Normal ratio: {normal_test_ratio * 100}%")
    print(f"tp: {tp}")
    print(f"fn: {fn}")
# Out:
# Normal ratio: 99.98544113365038%
# tp: 20603
# fn: 3

# %%
# Test model on normal data
with torch.no_grad():
    output = model(test_data)
    assert output.shape == test_data.shape, "The predicted data shape is not right!"
    mse_per_sample = [mean_squared_error(test_data[i], output[i]) for i in range(test_data.shape[0])]

    abnormal_test_ratio = sum([score > threshold for score in mse_per_sample])/float(len(mse_per_sample))
    print(f"Abnormal ratio: {abnormal_test_ratio * 100}%")
# Out:
# Abnormal ratio: 93.28657314629258%

# %%
# Test model on normal data
with torch.no_grad():
    output = model(real_abnormal_data)
    assert output.shape == real_abnormal_data.shape, "The predicted data shape is not right!"
    mse_per_sample = [mean_squared_error(real_abnormal_data[i], output[i]) for i in range(real_abnormal_data.shape[0])]

    abnormal_test_ratio = sum([score > threshold for score in mse_per_sample])/float(len(mse_per_sample))
    tn = len([score for score in mse_per_sample if score >= threshold])
    fp = len([score for score in mse_per_sample if score < threshold])
    print(f"Abnormal ratio: {abnormal_test_ratio * 100}%")
    print(f"tn: {tn}")
    print(f"fp: {fp}")
# Out:
# Abnormal ratio: 86.20689655172413%
# tn: 350
# fp: 56

# %%
plt.rcParams.update({'font.size': 18})
conf_matrix = np.array([[tn, fp], [fn, tp]])
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size="xx-large")

plt.xlabel('Predictions')
plt.ylabel('Actuals')
plt.title(DATASET_NAME, fontsize=26)
plt.show()

# %%
SKIP_PLOT = 2
with torch.no_grad():
    plt.title("Training curve")
    plt.plot(range(len(history['train_loss']) - SKIP_PLOT),history['train_loss'][SKIP_PLOT:],'r', label='train')
    plt.plot(range(len(history['val_loss']) - SKIP_PLOT),history['val_loss'][SKIP_PLOT:],'g', label='validation')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

# %%
model = model.cpu()
model.eval()
SKIP_PLOT = 2
with torch.no_grad():
    plt.title("Training curve")
    plt.plot(range(len(history['threshold']) - SKIP_PLOT),history['threshold'][SKIP_PLOT:],'r')
    plt.xlabel("Epoch")
    plt.ylabel("Threshold")
    plt.show()

# %%
model = model.cpu()
model.eval()
with torch.no_grad():
    plt.title("Training curve")
    plt.plot(range(len(history['abnormal_ratio'])),history['abnormal_ratio'],'r')
    plt.xlabel("Epoch")
    plt.ylabel("Abnormal accuracy")
    plt.show()

# %%
model = model.cpu()
model.eval()
with torch.no_grad():
    plt.title("Training curve")
    plt.plot(range(len(history['normal_train_ratio'])),history['normal_train_ratio'],'r')
    plt.plot(range(len(history['normal_valid_ratio'])),history['normal_valid_ratio'],'g')
    plt.xlabel("Epoch")
    plt.ylabel("Normal accuracy")
    plt.show()
