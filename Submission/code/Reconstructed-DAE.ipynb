# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, confusion_matrix
from torch.utils.data import SubsetRandomSampler, DataLoader
import matplotlib.pyplot as plt

# %%
import numpy as np
import torch
import torch.nn as nn
from data_processing import get_data


DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(DEVICE)
# Out:
# cuda:0

# %%
print(torch.cuda.device_count())
print(torch.cuda.current_device())
print(torch.cuda.get_device_name(0))
# Out:
# 1
# 0
# NVIDIA GeForce GTX 1050 Ti

# %%
DATASET_NAME = "rene"

# %%
normal_data, abnormal_data, real_abnormal_data, real_abnormal_data_2 = get_data(DATASET_NAME)
# Out:
# Normal data shape: (45341, 125)
# Abnormal data shape: (82, 125)
# Real abnormal data shape: (891, 125)
# Real abnormal data 2 shape: (891, 125)

# %%
# Transform torch tensors to keras tensors
normal_data = torch.Tensor(normal_data)
abnormal_data = torch.Tensor(abnormal_data)
real_abnormal_data = torch.Tensor(real_abnormal_data)
real_abnormal_data_2 = torch.Tensor(real_abnormal_data_2)

# %%
train_data = normal_data
test_data = torch.concat([abnormal_data, real_abnormal_data, real_abnormal_data_2])
print(train_data.shape)
print(test_data.shape)
# Out:
# torch.Size([45341, 125])
# torch.Size([1864, 125])

# %%
# Define the DAE
class DAE(nn.Module):
    def __init__(self,
                 input_size,
                 hidden_layers=(16,),
                 hidden_activation=nn.ReLU,
                 output_activation=nn.Sigmoid
                 ):
        super(DAE, self).__init__()
        self.input_size = input_size
        self.hidden_layers = hidden_layers
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation

        # Add the encoding layers
        self.encoded = self.create_layers(hidden_layers, input_size)

        # Add the decoding layers with the output activation function
        self.decoded = self.create_layers(hidden_layers[-2::-1], hidden_layers[-1])
        self.decoded.append(nn.Linear(hidden_layers[0], input_size))
        self.decoded.append(self.output_activation())

    def create_layers(self, design, input_size):
        layers = []
        for i, layer in enumerate(design):
            in_features = design[i-1] if i > 0 else input_size
            out_features = layer
            layers.append(nn.Linear(in_features, out_features))
            layers.append(self.hidden_activation())

        return nn.Sequential(*layers)

    def forward(self, input):
        encoded = self.encoded(input)
        # print(self.decoded)
        decoded = self.decoded(encoded)
        return decoded

# %%
# Define hyperparameters
BATCH_SIZE = 128
EPOCHS = 10
criterion = nn.MSELoss()
hidden_layers = (128,64,32,16,8)
learning_rate = 0.001

# Create the KFold object for cross validation
folds = 10
splits = KFold(n_splits=folds, shuffle=True, random_state=42)

# %%
# Define the model
model = DAE(input_size=train_data.shape[1], hidden_layers=hidden_layers).to(DEVICE)
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate)

# %%
### Get initial results on abnormal data before testing
model = model.cpu()
with torch.no_grad():
    # Compute a placeholder threshold
    output = model(train_data)
    assert output.shape == train_data.shape, "The predicted data shape is not right!"
    mse_per_sample = [mean_squared_error(train_data[i], output[i]) for i in range(output.shape[0])]
    normal_score = np.mean(mse_per_sample)
    threshold = normal_score + normal_score + 3 * (np.std(mse_per_sample) + np.std(mse_per_sample))

    # Test the abnormal data with the placeholder threshold
    output = model(test_data)
    mse_per_sample = [mean_squared_error(test_data[i], output[i]) for i in range(output.shape[0])]
    abnormal_test_ratio = sum([score > threshold for score in mse_per_sample])/float(len(mse_per_sample))
    print(f"Abnormal ratio: {abnormal_test_ratio}")
model = model.to(DEVICE)
# Out:
# Abnormal ratio: 0.0

# %%
print("Training the deep autoencoder")

history = {
    'train_score': [],
    'val_score': [],
    'train_loss': [],
    'val_loss': [],
    'threshold': [],
    'abnormal_ratio': [],
    'normal_train_ratio': [],
    'normal_valid_ratio': []
}

for fold, (train_idx, val_idx) in enumerate(splits.split(train_data)):
    print(f"Fold {fold+1}")
    train_sampler = SubsetRandomSampler(train_idx)
    validation_sampler = SubsetRandomSampler(val_idx)
    train_dataloader = DataLoader(train_data, batch_size=BATCH_SIZE, sampler=train_sampler)
    validation_dataloader = DataLoader(train_data, batch_size=BATCH_SIZE, sampler=validation_sampler)

    # Train the model on the scaled data
    for epoch in range(EPOCHS):
        total_train_loss = 0
        total_validation_loss = 0
        print(f"Epoch {epoch}")
        for i, trajectories in enumerate(train_dataloader):
            trajectories = trajectories.to(DEVICE, dtype=torch.float32)
            # print(type(trajectories[0]))

            # Forward pass
            model.zero_grad()
            output = model(trajectories)
            loss = criterion(output, trajectories)
            total_train_loss += loss / len(train_dataloader)

            # Backward pass
            loss.backward()
            optimizer.step()

        history['train_loss'].append(total_train_loss.cpu())

        # Evaluate model at this epoch
        model.eval()
        model = model.cpu()
        with torch.no_grad():
            # Get the training score
            mse_per_sample_train = []
            for i, trajectories in enumerate(train_dataloader):
                output = model(trajectories)
                assert output.shape == trajectories.shape, "The predicted data shape is not right!"
                mse_per_sample_train.extend([mean_squared_error(trajectories[i], output[i]) for i in range(output.shape[0])])
            train_score = np.mean(mse_per_sample_train)
            print(f"Train score: {train_score}")
            history['train_score'].append(train_score)

            # Get validation score
            mse_per_sample_validation = []
            for i, trajectories in enumerate(validation_dataloader):
                output = model(trajectories)
                assert output.shape == trajectories.shape, "The predicted data shape is not right!"
                mse_per_sample_validation.extend([mean_squared_error(trajectories[i], output[i]) for i in range(output.shape[0])])

                # Also get loss for rating model
                loss = criterion(output, trajectories)
                total_validation_loss += loss / len(validation_dataloader)
            validation_score = np.mean(mse_per_sample_validation)
            print(f"Validation score: {validation_score}")
            history['val_score'].append(validation_score)
            history['val_loss'].append(total_validation_loss)

            # Calculate threshold
            threshold = train_score + validation_score + 3 * (np.std(mse_per_sample_train) + np.std(mse_per_sample_validation))
            print(f"Threshold value: {threshold}")
            history['threshold'].append(threshold)

            normal_train_ratio = sum([score < threshold for score in mse_per_sample_train])/float(len(mse_per_sample_train))
            print(f"Normal train ratio: {normal_train_ratio * 100}%")
            normal_valid_ratio = sum([score < threshold for score in mse_per_sample_validation])/float(len(mse_per_sample_validation))
            print(f"Normal validation ratio: {normal_valid_ratio * 100}%")
            history['normal_train_ratio'].append(normal_train_ratio)
            history['normal_valid_ratio'].append(normal_valid_ratio)

            # Get the ratio of correctly labeled abnormal data
            predicted_test_data = model(test_data)
            assert predicted_test_data.shape == test_data.shape, "The predicted data shape is not right!"
            mse_per_sample = [mean_squared_error(test_data[i], predicted_test_data[i]) for i in range(test_data.shape[0])]

            abnormal_test_ratio = sum([score > threshold for score in mse_per_sample])/float(len(mse_per_sample))
            print(f"Abnormal ratio: {abnormal_test_ratio * 100}%")
            history['abnormal_ratio'].append(abnormal_test_ratio)
        model = model.to(DEVICE)
        model.train()
# Out:
# Training the deep autoencoder
# Fold 1
# Epoch 0
# Train score: 0.0031104013323783875
# Validation score: 0.0032459052745252848
# Threshold value: 0.04299202933907509
# Normal train ratio: 99.41185119835319%
# Normal validation ratio: 99.22822491730982%
# Abnormal ratio: 51.12660944206009%
# Epoch 1
# Train score: 0.0025340390857309103
# Validation score: 0.002562265843153
# Threshold value: 0.018182607367634773
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 87.1244635193133%
# Epoch 2
# Train score: 0.0024214372970163822
# Validation score: 0.002448518993332982
# Threshold value: 0.017514218110591173
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 86.64163090128756%
# Epoch 3
# Train score: 0.001760596758686006
# Validation score: 0.0017910486785694957
# Threshold value: 0.011398309608921409
# Normal train ratio: 99.98284565995196%
# Normal validation ratio: 99.9779492833517%
# Abnormal ratio: 94.25965665236052%
# Epoch 4
# Train score: 0.0013840687461197376
# Validation score: 0.0014181090518832207
# Threshold value: 0.00923053314909339
# Normal train ratio: 99.92158015978042%
# Normal validation ratio: 99.82359426681367%
# Abnormal ratio: 96.88841201716738%
# Epoch 5
# Train score: 0.0013416653964668512
# Validation score: 0.001370062935166061
# Threshold value: 0.008935971651226282
# Normal train ratio: 99.93138263980788%
# Normal validation ratio: 99.91179713340684%
# Abnormal ratio: 97.04935622317596%
# Epoch 6
# Train score: 0.0013143502874299884
# Validation score: 0.0013454273575916886
# Threshold value: 0.008816956076771021
# Normal train ratio: 99.93138263980788%
# Normal validation ratio: 99.91179713340684%
# Abnormal ratio: 97.04935622317596%
# Epoch 7
# Train score: 0.0012969174422323704
# Validation score: 0.0013215439394116402
# Threshold value: 0.008559304289519787
# Normal train ratio: 99.94363573984218%
# Normal validation ratio: 99.91179713340684%
# Abnormal ratio: 97.1030042918455%
# Epoch 8
# Train score: 0.0012798542156815529
# Validation score: 0.001306107733398676
# Threshold value: 0.008534882217645645
# Normal train ratio: 99.91912953977356%
# Normal validation ratio: 99.93384785005513%
# Abnormal ratio: 97.15665236051501%
# Epoch 9
# Train score: 0.0012733163312077522
# Validation score: 0.0012996940640732646
# Threshold value: 0.008478263858705759
# Normal train ratio: 99.92648139979414%
# Normal validation ratio: 99.86769570011025%
# Abnormal ratio: 97.15665236051501%
# Fold 2
# Epoch 0
# Train score: 0.0012701305095106363
# Validation score: 0.0012427300680428743
# Threshold value: 0.008129260269924998
# Normal train ratio: 99.89952704192908%
# Normal validation ratio: 99.86766651962947%
# Abnormal ratio: 96.99570815450643%
# Epoch 1
# Train score: 0.0012593466090038419
# Validation score: 0.001232299255207181
# Threshold value: 0.008002255577594042
# Normal train ratio: 99.90197760188202%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 96.83476394849787%
# Epoch 2
# Train score: 0.0012416505487635732
# Validation score: 0.001215208088979125
# Threshold value: 0.007886430015787482
# Normal train ratio: 99.90687872178793%
# Normal validation ratio: 99.95588883987648%
# Abnormal ratio: 96.40557939914163%
# Epoch 3
# Train score: 0.0012306823628023267
# Validation score: 0.0012050957884639502
# Threshold value: 0.007827925728634
# Normal train ratio: 99.89952704192908%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 96.03004291845494%
# Epoch 4
# Train score: 0.0012059691362082958
# Validation score: 0.0011810153955593705
# Threshold value: 0.007700785528868437
# Normal train ratio: 99.8799225623055%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 96.19098712446352%
# Epoch 5
# Train score: 0.0012151481350883842
# Validation score: 0.0011908957967534661
# Threshold value: 0.007716112304478884
# Normal train ratio: 99.90442816183499%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 95.7618025751073%
# Epoch 6
# Train score: 0.0011802787194028497
# Validation score: 0.0011568288318812847
# Threshold value: 0.0075591623317450285
# Normal train ratio: 99.87502144239959%
# Normal validation ratio: 99.91177767975297%
# Abnormal ratio: 95.70815450643777%
# Epoch 7
# Train score: 0.0011858484940603375
# Validation score: 0.0011612343369051814
# Threshold value: 0.007564269588328898
# Normal train ratio: 99.87257088244664%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 95.60085836909872%
# Epoch 8
# Train score: 0.0011678215814754367
# Validation score: 0.0011437213979661465
# Threshold value: 0.007511800853535533
# Normal train ratio: 99.8652192025878%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 95.0107296137339%
# Epoch 9
# Train score: 0.0011719787726178765
# Validation score: 0.0011492244666442275
# Threshold value: 0.007555063348263502
# Normal train ratio: 99.8603180826819%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 94.74248927038627%
# Fold 3
# Epoch 0
# Train score: 0.0011592338560149074
# Validation score: 0.001170140691101551
# Threshold value: 0.007607609964907169
# Normal train ratio: 99.88727424216434%
# Normal validation ratio: 99.86766651962947%
# Abnormal ratio: 94.47424892703863%
# Epoch 1
# Train score: 0.0011548605980351567
# Validation score: 0.0011653108522295952
# Threshold value: 0.007593763759359717
# Normal train ratio: 99.86766976254074%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 94.47424892703863%
# Epoch 2
# Train score: 0.0011662100441753864
# Validation score: 0.00117803446482867
# Threshold value: 0.007620067335665226
# Normal train ratio: 99.88237312225844%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 94.58154506437768%
# Epoch 3
# Train score: 0.0011696364963427186
# Validation score: 0.001181952771730721
# Threshold value: 0.007629138301126659
# Normal train ratio: 99.88237312225844%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 94.25965665236052%
# Epoch 4
# Train score: 0.001159448060207069
# Validation score: 0.0011697597801685333
# Threshold value: 0.007591546978801489
# Normal train ratio: 99.88237312225844%
# Normal validation ratio: 99.82355535950596%
# Abnormal ratio: 94.68884120171673%
# Epoch 5
# Train score: 0.0011563536245375872
# Validation score: 0.001167216571047902
# Threshold value: 0.007608401356264949
# Normal train ratio: 99.86766976254074%
# Normal validation ratio: 99.82355535950596%
# Abnormal ratio: 94.4206008583691%
# Epoch 6
# Train score: 0.0011468029115349054
# Validation score: 0.001157049206085503
# Threshold value: 0.007563549908809364
# Normal train ratio: 99.8799225623055%
# Normal validation ratio: 99.86766651962947%
# Abnormal ratio: 94.58154506437768%
# Epoch 7
# Train score: 0.0011491356417536736
# Validation score: 0.001160891493782401
# Threshold value: 0.007585996529087424
# Normal train ratio: 99.87012032249369%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 95.11802575107296%
# Epoch 8
# Train score: 0.0011567749315872788
# Validation score: 0.0011682793265208602
# Threshold value: 0.0075912196189165115
# Normal train ratio: 99.88972480211729%
# Normal validation ratio: 99.86766651962947%
# Abnormal ratio: 95.0107296137339%
# Epoch 9
# Train score: 0.0011434453772380948
# Validation score: 0.001154414494521916
# Threshold value: 0.007539904210716486
# Normal train ratio: 99.88482368221139%
# Normal validation ratio: 99.86766651962947%
# Abnormal ratio: 94.84978540772532%
# Fold 4
# Epoch 0
# Train score: 0.001144532347097993
# Validation score: 0.001141381566412747
# Threshold value: 0.007508888840675354
# Normal train ratio: 99.88237312225844%
# Normal validation ratio: 99.91177767975297%
# Abnormal ratio: 95.3862660944206%
# Epoch 1
# Train score: 0.0011475469218567014
# Validation score: 0.0011437644716352224
# Threshold value: 0.007499708794057369
# Normal train ratio: 99.87747200235255%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 95.06437768240343%
# Epoch 2
# Train score: 0.0012007801560685039
# Validation score: 0.0011983814183622599
# Threshold value: 0.007680084207095206
# Normal train ratio: 99.89707648197613%
# Normal validation ratio: 99.93383325981473%
# Abnormal ratio: 95.11802575107296%
# Epoch 3
# Train score: 0.0011491224868223071
# Validation score: 0.0011451522586867213
# Threshold value: 0.007493095006793737
# Normal train ratio: 99.87747200235255%
# Normal validation ratio: 99.91177767975297%
# Abnormal ratio: 95.3862660944206%
# Epoch 4
# Train score: 0.0011492990888655186
# Validation score: 0.0011460944078862667
# Threshold value: 0.007512264186516404
# Normal train ratio: 99.88237312225844%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 95.3862660944206%
# Epoch 5
# Train score: 0.0011434821644797921
# Validation score: 0.0011411255691200495
# Threshold value: 0.007485157228074968
# Normal train ratio: 99.86276864263485%
# Normal validation ratio: 99.91177767975297%
# Abnormal ratio: 95.49356223175965%
# Epoch 6
# Train score: 0.0011375286849215627
# Validation score: 0.0011335959425196052
# Threshold value: 0.007472028839401901
# Normal train ratio: 99.88237312225844%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 95.70815450643777%
# Epoch 7
# Train score: 0.0011421132367104292
# Validation score: 0.0011381086660549045
# Threshold value: 0.007472689962014556
# Normal train ratio: 99.87012032249369%
# Normal validation ratio: 99.91177767975297%
# Abnormal ratio: 95.60085836909872%
# Epoch 8
# Train score: 0.0011378199560567737
# Validation score: 0.0011352736037224531
# Threshold value: 0.007464942755177617
# Normal train ratio: 99.8799225623055%
# Normal validation ratio: 99.91177767975297%
# Abnormal ratio: 95.70815450643777%
# Epoch 9
# Train score: 0.0011410900624468923
# Validation score: 0.001137480023317039
# Threshold value: 0.007474116166122258
# Normal train ratio: 99.87012032249369%
# Normal validation ratio: 99.91177767975297%
# Abnormal ratio: 95.49356223175965%
# Fold 5
# Epoch 0
# Train score: 0.0012030700454488397
# Validation score: 0.001198456739075482
# Threshold value: 0.007608254672959447
# Normal train ratio: 99.88727424216434%
# Normal validation ratio: 99.91177767975297%
# Abnormal ratio: 95.3862660944206%
# Epoch 1
# Train score: 0.0011414132313802838
# Validation score: 0.0011374857276678085
# Threshold value: 0.007431796053424478
# Normal train ratio: 99.87502144239959%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 95.7618025751073%
# Epoch 2
# Train score: 0.0011363563826307654
# Validation score: 0.001132066361606121
# Threshold value: 0.0074193356558680534
# Normal train ratio: 99.87502144239959%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 95.70815450643777%
# Epoch 3
# Train score: 0.00113737175706774
# Validation score: 0.001132256118580699
# Threshold value: 0.007409481913782656
# Normal train ratio: 99.85786752272894%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 95.86909871244636%
# Epoch 4
# Train score: 0.0011437369976192713
# Validation score: 0.001140254782512784
# Threshold value: 0.0074322817381471395
# Normal train ratio: 99.87502144239959%
# Normal validation ratio: 99.91177767975297%
# Abnormal ratio: 95.81545064377683%
# Epoch 5
# Train score: 0.001143736531957984
# Validation score: 0.001139846513979137
# Threshold value: 0.0074197156354784966
# Normal train ratio: 99.87257088244664%
# Normal validation ratio: 99.91177767975297%
# Abnormal ratio: 95.97639484978541%
# Epoch 6
# Train score: 0.001145645510405302
# Validation score: 0.0011418068315833807
# Threshold value: 0.007426593801937997
# Normal train ratio: 99.87502144239959%
# Normal validation ratio: 99.91177767975297%
# Abnormal ratio: 95.65450643776823%
# Epoch 7
# Train score: 0.0011354906018823385
# Validation score: 0.0011312136193737388
# Threshold value: 0.007398874964565039
# Normal train ratio: 99.85786752272894%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 95.86909871244636%
# Epoch 8
# Train score: 0.0011358159827068448
# Validation score: 0.001131966826505959
# Threshold value: 0.00739978498313576
# Normal train ratio: 99.86766976254074%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 95.81545064377683%
# Epoch 9
# Train score: 0.0011375609319657087
# Validation score: 0.0011334841838106513
# Threshold value: 0.007395561435259879
# Normal train ratio: 99.87257088244664%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 95.97639484978541%
# Fold 6
# Epoch 0
# Train score: 0.001130085438489914
# Validation score: 0.0011265676002949476
# Threshold value: 0.007461965782567859
# Normal train ratio: 99.88727424216434%
# Normal validation ratio: 99.82355535950596%
# Abnormal ratio: 95.81545064377683%
# Epoch 1
# Train score: 0.0011380373034626245
# Validation score: 0.001135374535806477
# Threshold value: 0.007494440069422126
# Normal train ratio: 99.8799225623055%
# Normal validation ratio: 99.8014997794442%
# Abnormal ratio: 95.7618025751073%
# Epoch 2
# Train score: 0.0011346680112183094
# Validation score: 0.0011315506417304277
# Threshold value: 0.007478384301066399
# Normal train ratio: 99.89462592202318%
# Normal validation ratio: 99.8014997794442%
# Abnormal ratio: 95.81545064377683%
# Epoch 3
# Train score: 0.0011315938318148255
# Validation score: 0.0011300691403448582
# Threshold value: 0.007485487032681704
# Normal train ratio: 99.89217536207023%
# Normal validation ratio: 99.82355535950596%
# Abnormal ratio: 95.49356223175965%
# Epoch 4
# Train score: 0.0011303601786494255
# Validation score: 0.0011280833277851343
# Threshold value: 0.007466535898856819
# Normal train ratio: 99.87747200235255%
# Normal validation ratio: 99.8014997794442%
# Abnormal ratio: 95.65450643776823%
# Epoch 5
# Train score: 0.0011672156397253275
# Validation score: 0.0011642855824902654
# Threshold value: 0.00758596695959568
# Normal train ratio: 99.90687872178793%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 95.22532188841201%
# Epoch 6
# Train score: 0.001133084879256785
# Validation score: 0.0011309070978313684
# Threshold value: 0.007486200658604503
# Normal train ratio: 99.88237312225844%
# Normal validation ratio: 99.82355535950596%
# Abnormal ratio: 95.54721030042919%
# Epoch 7
# Train score: 0.0011550374329090118
# Validation score: 0.001153231831267476
# Threshold value: 0.007559054880402982
# Normal train ratio: 99.89462592202318%
# Normal validation ratio: 99.73533303925893%
# Abnormal ratio: 95.27896995708154%
# Epoch 8
# Train score: 0.0011319811455905437
# Validation score: 0.0011302935890853405
# Threshold value: 0.0074817046988755465
# Normal train ratio: 99.88237312225844%
# Normal validation ratio: 99.77944419938244%
# Abnormal ratio: 95.49356223175965%
# Epoch 9
# Train score: 0.0011294352589175105
# Validation score: 0.0011272367555648088
# Threshold value: 0.0074590034782886505
# Normal train ratio: 99.88237312225844%
# Normal validation ratio: 99.82355535950596%
# Abnormal ratio: 95.22532188841201%
# Fold 7
# Epoch 0
# Train score: 0.0011302841594442725
# Validation score: 0.0011256993748247623
# Threshold value: 0.007430644123815
# Normal train ratio: 99.88237312225844%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 95.06437768240343%
# Epoch 1
# Train score: 0.001127182855270803
# Validation score: 0.001121990499086678
# Threshold value: 0.00742024602368474
# Normal train ratio: 99.87747200235255%
# Normal validation ratio: 99.82355535950596%
# Abnormal ratio: 94.84978540772532%
# Epoch 2
# Train score: 0.0011246174108237028
# Validation score: 0.001120085595175624
# Threshold value: 0.007425118004903197
# Normal train ratio: 99.88482368221139%
# Normal validation ratio: 99.82355535950596%
# Abnormal ratio: 94.90343347639485%
# Epoch 3
# Train score: 0.001128223491832614
# Validation score: 0.0011236366117373109
# Threshold value: 0.007435482693836093
# Normal train ratio: 99.88237312225844%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 94.7961373390558%
# Epoch 4
# Train score: 0.0011266787769272923
# Validation score: 0.001122346380725503
# Threshold value: 0.007421826012432575
# Normal train ratio: 99.8799225623055%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 94.74248927038627%
# Epoch 5
# Train score: 0.00112658622674644
# Validation score: 0.0011218796717002988
# Threshold value: 0.007415586616843939
# Normal train ratio: 99.88237312225844%
# Normal validation ratio: 99.86766651962947%
# Abnormal ratio: 94.68884120171673%
# Epoch 6
# Train score: 0.0011253203265368938
# Validation score: 0.0011205560294911265
# Threshold value: 0.0074145609978586435
# Normal train ratio: 99.88237312225844%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 94.52789699570815%
# Epoch 7
# Train score: 0.0011280205799266696
# Validation score: 0.0011226048227399588
# Threshold value: 0.007534904987551272
# Normal train ratio: 99.8260102433406%
# Normal validation ratio: 99.7573886193207%
# Abnormal ratio: 93.88412017167383%
# Epoch 8
# Train score: 0.0011325067607685924
# Validation score: 0.0011279823957011104
# Threshold value: 0.007428503828123212
# Normal train ratio: 99.88482368221139%
# Normal validation ratio: 99.82355535950596%
# Abnormal ratio: 94.58154506437768%
# Epoch 9
# Train score: 0.001122988061979413
# Validation score: 0.0011183451861143112
# Threshold value: 0.007402306422591209
# Normal train ratio: 99.8652192025878%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 94.52789699570815%
# Fold 8
# Epoch 0
# Train score: 0.0011222673347219825
# Validation score: 0.001126526272855699
# Threshold value: 0.007358978735283017
# Normal train ratio: 99.86276864263485%
# Normal validation ratio: 99.91177767975297%
# Abnormal ratio: 94.58154506437768%
# Epoch 1
# Train score: 0.0011242550099268556
# Validation score: 0.0011286226799711585
# Threshold value: 0.007373120402917266
# Normal train ratio: 99.86276864263485%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 94.4206008583691%
# Epoch 2
# Train score: 0.001122879795730114
# Validation score: 0.0011278499150648713
# Threshold value: 0.007360284682363272
# Normal train ratio: 99.86766976254074%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 94.52789699570815%
# Epoch 3
# Train score: 0.0011195676634088159
# Validation score: 0.0011242978507652879
# Threshold value: 0.007352615939453244
# Normal train ratio: 99.86276864263485%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 94.36695278969958%
# Epoch 4
# Train score: 0.0011224200716242194
# Validation score: 0.0011269315145909786
# Threshold value: 0.007366762030869722
# Normal train ratio: 99.8505158428701%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 94.25965665236052%
# Epoch 5
# Train score: 0.0011187661439180374
# Validation score: 0.0011230061063542962
# Threshold value: 0.007343791541643441
# Normal train ratio: 99.8505158428701%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 94.15236051502146%
# Epoch 6
# Train score: 0.0011126806493848562
# Validation score: 0.001117807230912149
# Threshold value: 0.007302053272724152
# Normal train ratio: 99.85541696277599%
# Normal validation ratio: 99.91177767975297%
# Abnormal ratio: 94.36695278969958%
# Epoch 7
# Train score: 0.0011105616576969624
# Validation score: 0.0011156550608575344
# Threshold value: 0.0072932615876197815
# Normal train ratio: 99.85541696277599%
# Normal validation ratio: 99.91177767975297%
# Abnormal ratio: 94.47424892703863%
# Epoch 8
# Train score: 0.0011093306820839643
# Validation score: 0.0011138139525428414
# Threshold value: 0.007276783464476466
# Normal train ratio: 99.85541696277599%
# Normal validation ratio: 99.88972209969123%
# Abnormal ratio: 94.47424892703863%
# Epoch 9
# Train score: 0.0011094824876636267
# Validation score: 0.0011135365348309278
# Threshold value: 0.007272881688550115
# Normal train ratio: 99.85541696277599%
# Normal validation ratio: 99.86766651962947%
# Abnormal ratio: 94.31330472103005%
# Fold 9
# Epoch 0
# Train score: 0.0011074256617575884
# Validation score: 0.0011100975098088384
# Threshold value: 0.007237238343805075
# Normal train ratio: 99.85541696277599%
# Normal validation ratio: 99.86766651962947%
# Abnormal ratio: 94.47424892703863%
# Epoch 1
# Train score: 0.001107403077185154
# Validation score: 0.0011108623584732413
# Threshold value: 0.007240710663609207
# Normal train ratio: 99.8456147229642%
# Normal validation ratio: 99.86766651962947%
# Abnormal ratio: 94.36695278969958%
# Epoch 2
# Train score: 0.0011036611394956708
# Validation score: 0.0011078614043071866
# Threshold value: 0.0072329932590946555
# Normal train ratio: 99.84316416301124%
# Normal validation ratio: 99.86766651962947%
# Abnormal ratio: 94.31330472103005%
# Epoch 3
# Train score: 0.0011021083919331431
# Validation score: 0.0011057198280468583
# Threshold value: 0.007236495497636497
# Normal train ratio: 99.85786752272894%
# Normal validation ratio: 99.86766651962947%
# Abnormal ratio: 94.36695278969958%
# Epoch 4
# Train score: 0.0011093264911323786
# Validation score: 0.0011133700609207153
# Threshold value: 0.0072556930826976895
# Normal train ratio: 99.8505158428701%
# Normal validation ratio: 99.86766651962947%
# Abnormal ratio: 94.47424892703863%
# Epoch 5
# Train score: 0.001110234297811985
# Validation score: 0.0011144643649458885
# Threshold value: 0.007248406298458576
# Normal train ratio: 99.8505158428701%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 94.47424892703863%
# Epoch 6
# Train score: 0.0011079871328547597
# Validation score: 0.0011123163858428597
# Threshold value: 0.00723910634405911
# Normal train ratio: 99.84806528291715%
# Normal validation ratio: 99.86766651962947%
# Abnormal ratio: 94.36695278969958%
# Epoch 7
# Train score: 0.0011041592806577682
# Validation score: 0.0011089569889008999
# Threshold value: 0.007236882229335606
# Normal train ratio: 99.85296640282304%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 94.63519313304721%
# Epoch 8
# Train score: 0.0011021257378160954
# Validation score: 0.0011062262346968055
# Threshold value: 0.00722935376688838
# Normal train ratio: 99.84806528291715%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 94.58154506437768%
# Epoch 9
# Train score: 0.0011013710172846913
# Validation score: 0.0011051954934373498
# Threshold value: 0.00722596375271678
# Normal train ratio: 99.84806528291715%
# Normal validation ratio: 99.82355535950596%
# Abnormal ratio: 94.47424892703863%
# Fold 10
# Epoch 0
# Train score: 0.0011008860310539603
# Validation score: 0.0011102298740297556
# Threshold value: 0.007297840667888522
# Normal train ratio: 99.86276864263485%
# Normal validation ratio: 99.82355535950596%
# Abnormal ratio: 94.68884120171673%
# Epoch 1
# Train score: 0.001099461573176086
# Validation score: 0.0011093462817370892
# Threshold value: 0.007292996626347303
# Normal train ratio: 99.8652192025878%
# Normal validation ratio: 99.86766651962947%
# Abnormal ratio: 94.58154506437768%
# Epoch 2
# Train score: 0.001101876376196742
# Validation score: 0.0011122042778879404
# Threshold value: 0.0073184260400012136
# Normal train ratio: 99.85296640282304%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 94.52789699570815%
# Epoch 3
# Train score: 0.0010994162876158953
# Validation score: 0.0011098608374595642
# Threshold value: 0.007283145561814308
# Normal train ratio: 99.8652192025878%
# Normal validation ratio: 99.8014997794442%
# Abnormal ratio: 94.63519313304721%
# Epoch 4
# Train score: 0.0011036628857254982
# Validation score: 0.001114742481149733
# Threshold value: 0.007314094575121999
# Normal train ratio: 99.86766976254074%
# Normal validation ratio: 99.82355535950596%
# Abnormal ratio: 94.7961373390558%
# Epoch 5
# Train score: 0.001098279724828899
# Validation score: 0.0011087610619142652
# Threshold value: 0.007286985055543482
# Normal train ratio: 99.8652192025878%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 94.68884120171673%
# Epoch 6
# Train score: 0.0010958955390378833
# Validation score: 0.0011070524342358112
# Threshold value: 0.007277403259649873
# Normal train ratio: 99.85541696277599%
# Normal validation ratio: 99.82355535950596%
# Abnormal ratio: 94.68884120171673%
# Epoch 7
# Train score: 0.001097648637369275
# Validation score: 0.0011088753817602992
# Threshold value: 0.007277298718690872
# Normal train ratio: 99.8603180826819%
# Normal validation ratio: 99.82355535950596%
# Abnormal ratio: 94.58154506437768%
# Epoch 8
# Train score: 0.001096550840884447
# Validation score: 0.0011076214723289013
# Threshold value: 0.00728102819994092
# Normal train ratio: 99.8652192025878%
# Normal validation ratio: 99.8456109395677%
# Abnormal ratio: 94.63519313304721%
# Epoch 9
# Train score: 0.0010976624907925725
# Validation score: 0.0011089659528806806
# Threshold value: 0.007278651813976467
# Normal train ratio: 99.87257088244664%
# Normal validation ratio: 99.8014997794442%
# Abnormal ratio: 94.63519313304721%

# %%
print(threshold)
# Out:
# 0.007278651813976467

# %%
model = model.cpu()
model.eval()
# Out:
# DAE(
#   (encoded): Sequential(
#     (0): Linear(in_features=125, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=32, out_features=16, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=16, out_features=8, bias=True)
#     (9): ReLU()
#   )
#   (decoded): Sequential(
#     (0): Linear(in_features=8, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=128, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=125, bias=True)
#     (9): Sigmoid()
#   )
# )

# %%
# Test model on normal data
with torch.no_grad():
    output = model(train_data)
    assert output.shape == train_data.shape, "The predicted data shape is not right!"
    mse_per_sample = [mean_squared_error(train_data[i], output[i]) for i in range(train_data.shape[0])]

    normal_test_ratio = sum([score < threshold for score in mse_per_sample])/float(len(mse_per_sample))
    tp = len([score for score in mse_per_sample if score < threshold])
    fn = len([score for score in mse_per_sample if score >= threshold])
    print(f"Normal ratio: {normal_test_ratio * 100}%")
    print(f"tp: {tp}")
    print(f"fn: {fn}")
# Out:
# Normal ratio: 99.86546392889439%
# tp: 45280
# fn: 61

# %%
# Test model on normal data
with torch.no_grad():
    output = model(test_data)
    assert output.shape == test_data.shape, "The predicted data shape is not right!"
    mse_per_sample = [mean_squared_error(test_data[i], output[i]) for i in range(test_data.shape[0])]

    abnormal_test_ratio = sum([score > threshold for score in mse_per_sample])/float(len(mse_per_sample))
    print(f"Abnormal ratio: {abnormal_test_ratio * 100}%")
# Out:
# Abnormal ratio: 94.63519313304721%

# %%
# Test model on normal data
with torch.no_grad():
    output = model(real_abnormal_data)
    assert output.shape == real_abnormal_data.shape, "The predicted data shape is not right!"
    mse_per_sample = [mean_squared_error(real_abnormal_data[i], output[i]) for i in range(real_abnormal_data.shape[0])]

    abnormal_test_ratio = sum([score > threshold for score in mse_per_sample])/float(len(mse_per_sample))
    tn = len([score for score in mse_per_sample if score >= threshold])
    fp = len([score for score in mse_per_sample if score < threshold])
    print(f"Abnormal ratio: {abnormal_test_ratio * 100}%")
    print(f"tn: {tn}")
    print(f"fp: {fp}")
# Out:
# Abnormal ratio: 95.51066217732884%
# tn: 851
# fp: 40

# %%
plt.rcParams.update({'font.size': 18})
conf_matrix = np.array([[tn, fp], [fn, tp]])
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size="xx-large")

plt.xlabel('Predictions')
plt.ylabel('Actuals')
plt.title(DATASET_NAME, fontsize=26)
plt.show()

# %%
SKIP_PLOT = 2
with torch.no_grad():
    plt.title("Training curve")
    plt.plot(range(len(history['train_loss']) - SKIP_PLOT),history['train_loss'][SKIP_PLOT:],'r', label='train')
    plt.plot(range(len(history['val_loss']) - SKIP_PLOT),history['val_loss'][SKIP_PLOT:],'g', label='validation')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

# %%
model = model.cpu()
model.eval()
SKIP_PLOT = 2
with torch.no_grad():
    plt.title("Training curve")
    plt.plot(range(len(history['threshold']) - SKIP_PLOT),history['threshold'][SKIP_PLOT:],'r')
    plt.xlabel("Epoch")
    plt.ylabel("Threshold")
    plt.show()

# %%
model = model.cpu()
model.eval()
with torch.no_grad():
    plt.title("Training curve")
    plt.plot(range(len(history['abnormal_ratio'])),history['abnormal_ratio'],'r')
    plt.xlabel("Epoch")
    plt.ylabel("Abnormal accuracy")
    plt.show()

# %%
model = model.cpu()
model.eval()
with torch.no_grad():
    plt.title("Training curve")
    plt.plot(range(len(history['normal_train_ratio'])),history['normal_train_ratio'],'r', label="train")
    plt.plot(range(len(history['normal_valid_ratio'])),history['normal_valid_ratio'],'g', label="validation")
    plt.xlabel("Epoch")
    plt.ylabel("Normal accuracy")
    plt.legend()
    plt.show()
