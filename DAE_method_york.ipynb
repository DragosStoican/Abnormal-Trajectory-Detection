# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from torch.utils.data import SubsetRandomSampler, DataLoader
import matplotlib.pyplot as plt

# %%
import numpy as np
import torch
import torch.nn as nn
from data_processing import get_data


DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(DEVICE)
# Out:
# cuda:0

# %%
print(torch.cuda.device_count())
print(torch.cuda.current_device())
print(torch.cuda.get_device_name(0))
# Out:
# 1
# 0
# NVIDIA GeForce GTX 1050 Ti

# %%
DATASET_NAME = "york"

# %%
normal_data, abnormal_data, _, _ = get_data(DATASET_NAME)
# Out:
# Normal data shape: (8200, 101)
# Abnormal data shape: (1620, 101)
# Real abnormal data shape: (2, 1)
# Real abnormal data 2 shape: (2, 1)
# C:\Users\drago\anaconda3\envs\Abnormal-Trajectory-Detection\lib\site-packages\sklearn\preprocessing\_data.py:473: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\Users\drago\anaconda3\envs\Abnormal-Trajectory-Detection\lib\site-packages\sklearn\preprocessing\_data.py:474: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
# C:\Users\drago\anaconda3\envs\Abnormal-Trajectory-Detection\lib\site-packages\sklearn\preprocessing\_data.py:473: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\Users\drago\anaconda3\envs\Abnormal-Trajectory-Detection\lib\site-packages\sklearn\preprocessing\_data.py:474: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %%
# Transform torch tensors to keras tensors
normal_data = torch.Tensor(normal_data)
abnormal_data = torch.Tensor(abnormal_data)

# %%
train_data = normal_data
test_data = abnormal_data
print(train_data.shape)
print(test_data.shape)
# Out:
# torch.Size([8200, 101])
# torch.Size([1620, 101])

# %%
# Define the DAE
class DAE(nn.Module):
    def __init__(self,
                 input_size,
                 hidden_layers=(16,),
                 hidden_activation=nn.ReLU,
                 output_activation=nn.Sigmoid
                 ):
        super(DAE, self).__init__()
        self.input_size = input_size
        self.hidden_layers = hidden_layers
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation

        # Add the encoding layers
        self.encoded = self.create_layers(hidden_layers, input_size)

        # Add the decoding layers with the output activation function
        self.decoded = self.create_layers(hidden_layers[-2::-1], hidden_layers[-1])
        self.decoded.append(nn.Linear(hidden_layers[0], input_size))
        self.decoded.append(self.output_activation())

    def create_layers(self, design, input_size):
        layers = []
        for i, layer in enumerate(design):
            in_features = design[i-1] if i > 0 else input_size
            out_features = layer
            layers.append(nn.Linear(in_features, out_features))
            layers.append(self.hidden_activation())

        return nn.Sequential(*layers)

    def forward(self, input):
        encoded = self.encoded(input)
        # print(self.decoded)
        decoded = self.decoded(encoded)
        return decoded

# %%
# Define hyperparameters
BATCH_SIZE = 128
EPOCHS = 10
criterion = nn.MSELoss()
hidden_layers = (128,64,32,16,8)
learning_rate = 0.001

# Create the KFold object for cross validation
folds = 10
splits = KFold(n_splits=folds, shuffle=True, random_state=42)

# %%
# Define the model
model = DAE(input_size=train_data.shape[1], hidden_layers=hidden_layers).to(DEVICE)
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate)

# %%
### Get initial results on abnormal data before testing
model = model.cpu()
with torch.no_grad():
    # Compute a placeholder threshold
    output = model(train_data)
    assert output.shape == train_data.shape, "The predicted data shape is not right!"
    mse_per_sample = [mean_squared_error(train_data[i], output[i]) for i in range(output.shape[0])]
    normal_score = np.mean(mse_per_sample)
    threshold = normal_score + normal_score + 3 * (np.std(mse_per_sample) + np.std(mse_per_sample))

    # Test the abnormal data with the placeholder threshold
    output = model(test_data)
    mse_per_sample = [mean_squared_error(test_data[i], output[i]) for i in range(output.shape[0])]
    abnormal_test_ratio = sum([score > threshold for score in mse_per_sample])/float(len(mse_per_sample))
    print(f"Abnormal ratio: {abnormal_test_ratio}")
model = model.to(DEVICE)
# Out:
# Abnormal ratio: 0.0

# %%
print("Training the deep autoencoder")

history = {
    'train_score': [],
    'val_score': [],
    'train_loss': [],
    'val_loss': [],
    'threshold': [],
    'abnormal_ratio': [],
    'normal_train_ratio': [],
    'normal_valid_ratio': []
}

for fold, (train_idx, val_idx) in enumerate(splits.split(train_data)):
    print(f"Fold {fold+1}")
    train_sampler = SubsetRandomSampler(train_idx)
    validation_sampler = SubsetRandomSampler(val_idx)
    train_dataloader = DataLoader(train_data, batch_size=BATCH_SIZE, sampler=train_sampler)
    validation_dataloader = DataLoader(train_data, batch_size=BATCH_SIZE, sampler=validation_sampler)

    # Train the model on the scaled data
    for epoch in range(EPOCHS):
        total_train_loss = 0
        total_validation_loss = 0
        print(f"Epoch {epoch}")
        for i, trajectories in enumerate(train_dataloader):
            trajectories = trajectories.to(DEVICE, dtype=torch.float32)
            # print(type(trajectories[0]))

            # Forward pass
            model.zero_grad()
            output = model(trajectories)
            loss = criterion(output, trajectories)
            total_train_loss += loss / len(train_dataloader)

            # Backward pass
            loss.backward()
            optimizer.step()

        history['train_loss'].append(total_train_loss.cpu())

        # Evaluate model at this epoch
        model.eval()
        model = model.cpu()
        with torch.no_grad():
            # Get the training score
            mse_per_sample_train = []
            for i, trajectories in enumerate(train_dataloader):
                output = model(trajectories)
                assert output.shape == trajectories.shape, "The predicted data shape is not right!"
                mse_per_sample_train.extend([mean_squared_error(trajectories[i], output[i]) for i in range(output.shape[0])])
            train_score = np.mean(mse_per_sample_train)
            print(f"Train score: {train_score}")
            history['train_score'].append(train_score)

            # Get validation score
            mse_per_sample_validation = []
            for i, trajectories in enumerate(validation_dataloader):
                output = model(trajectories)
                assert output.shape == trajectories.shape, "The predicted data shape is not right!"
                mse_per_sample_validation.extend([mean_squared_error(trajectories[i], output[i]) for i in range(output.shape[0])])

                # Also get loss for rating model
                loss = criterion(output, trajectories)
                total_validation_loss += loss / len(validation_dataloader)
            validation_score = np.mean(mse_per_sample_validation)
            print(f"Validation score: {validation_score}")
            history['val_score'].append(validation_score)
            history['val_loss'].append(total_validation_loss)

            # Calculate threshold
            threshold = train_score + validation_score + 3 * (np.std(mse_per_sample_train) + np.std(mse_per_sample_validation))
            print(f"Threshold value: {threshold}")
            history['threshold'].append(threshold)

            normal_train_ratio = sum([score < threshold for score in mse_per_sample_train])/float(len(mse_per_sample_train))
            print(f"Normal train ratio: {normal_train_ratio * 100}%")
            normal_valid_ratio = sum([score < threshold for score in mse_per_sample_validation])/float(len(mse_per_sample_validation))
            print(f"Normal validation ratio: {normal_valid_ratio * 100}%")
            history['normal_train_ratio'].append(normal_train_ratio)
            history['normal_valid_ratio'].append(normal_valid_ratio)

            # Get the ratio of correctly labeled abnormal data
            predicted_test_data = model(test_data)
            assert predicted_test_data.shape == test_data.shape, "The predicted data shape is not right!"
            mse_per_sample = [mean_squared_error(test_data[i], predicted_test_data[i]) for i in range(test_data.shape[0])]

            abnormal_test_ratio = sum([score > threshold for score in mse_per_sample])/float(len(mse_per_sample))
            print(f"Abnormal ratio: {abnormal_test_ratio * 100}%")
            history['abnormal_ratio'].append(abnormal_test_ratio)
        model = model.to(DEVICE)
        model.train()
# Out:
# Training the deep autoencoder
# Fold 1
# Epoch 0
# Train score: 0.04823099449276924
# Validation score: 0.048115819692611694
# Threshold value: 0.3224898427724838
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 0.0%
# Epoch 1
# Train score: 0.00498249102383852
# Validation score: 0.005156832281500101
# Threshold value: 0.051783205941319466
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 0.6172839506172839%
# Epoch 2
# Train score: 0.0016052891733124852
# Validation score: 0.001582674914970994
# Threshold value: 0.010029257507994771
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 23.51851851851852%
# Epoch 3
# Train score: 0.0015115314163267612
# Validation score: 0.0014824251411482692
# Threshold value: 0.009922518860548735
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 24.074074074074073%
# Epoch 4
# Train score: 0.0015115451533347368
# Validation score: 0.0014849274884909391
# Threshold value: 0.009963208809494972
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 21.604938271604937%
# Epoch 5
# Train score: 0.0014417555648833513
# Validation score: 0.0014071045443415642
# Threshold value: 0.009869103552773595
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 22.22222222222222%
# Epoch 6
# Train score: 0.0014834878966212273
# Validation score: 0.0014610649086534977
# Threshold value: 0.00986673915758729
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 23.39506172839506%
# Epoch 7
# Train score: 0.0013631631154567003
# Validation score: 0.0013341833837330341
# Threshold value: 0.009814596502110362
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 22.839506172839506%
# Epoch 8
# Train score: 0.0012665719259530306
# Validation score: 0.0012403293512761593
# Threshold value: 0.009100954281166196
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 17.530864197530864%
# Epoch 9
# Train score: 0.0012989628594368696
# Validation score: 0.0012761055259034038
# Threshold value: 0.009551153052598238
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 16.728395061728396%
# Fold 2
# Epoch 0
# Train score: 0.0012137534795328975
# Validation score: 0.0012454002862796187
# Threshold value: 0.00942508946172893
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 16.85185185185185%
# Epoch 1
# Train score: 0.0012116138823330402
# Validation score: 0.0012436904944479465
# Threshold value: 0.009291396010667086
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 18.086419753086417%
# Epoch 2
# Train score: 0.0011960490373894572
# Validation score: 0.0012225403916090727
# Threshold value: 0.00951636815443635
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 16.790123456790123%
# Epoch 3
# Train score: 0.001165199326351285
# Validation score: 0.0011914584320038557
# Threshold value: 0.009265090804547071
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 18.88888888888889%
# Epoch 4
# Train score: 0.0011615992989391088
# Validation score: 0.001184931956231594
# Threshold value: 0.009095403598621488
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 19.1358024691358%
# Epoch 5
# Train score: 0.0012053755344823003
# Validation score: 0.0012320451205596328
# Threshold value: 0.009522137697786093
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 19.012345679012345%
# Epoch 6
# Train score: 0.0011619343422353268
# Validation score: 0.0011871258029714227
# Threshold value: 0.009093208471313119
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 19.814814814814817%
# Epoch 7
# Train score: 0.0011559015838429332
# Validation score: 0.0011844062246382236
# Threshold value: 0.008854909567162395
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 21.604938271604937%
# Epoch 8
# Train score: 0.0012563669588416815
# Validation score: 0.0012927564093843102
# Threshold value: 0.009480496402829885
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 19.753086419753085%
# Epoch 9
# Train score: 0.001158920000307262
# Validation score: 0.001188779599033296
# Threshold value: 0.009068056708201766
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 20.8641975308642%
# Fold 3
# Epoch 0
# Train score: 0.0011706181103363633
# Validation score: 0.0011291767004877329
# Threshold value: 0.008825581520795822
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 26.41975308641975%
# Epoch 1
# Train score: 0.0011431799503043294
# Validation score: 0.0011006545973941684
# Threshold value: 0.008843946969136596
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 26.913580246913583%
# Epoch 2
# Train score: 0.0011483862763270736
# Validation score: 0.001116471947170794
# Threshold value: 0.008508005645126104
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 26.41975308641975%
# Epoch 3
# Train score: 0.0011054410133510828
# Validation score: 0.0010571262100711465
# Threshold value: 0.00850170012563467
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 27.160493827160494%
# Epoch 4
# Train score: 0.001098895212635398
# Validation score: 0.0010670869378373027
# Threshold value: 0.008108465000987053
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 27.962962962962962%
# Epoch 5
# Train score: 0.001097035827115178
# Validation score: 0.0010657439706847072
# Threshold value: 0.00813925126567483
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 28.271604938271604%
# Epoch 6
# Train score: 0.0010993799660354853
# Validation score: 0.0010594826890155673
# Threshold value: 0.008289651945233345
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 28.39506172839506%
# Epoch 7
# Train score: 0.0010836415458470583
# Validation score: 0.0010447812965139747
# Threshold value: 0.008051864802837372
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 28.39506172839506%
# Epoch 8
# Train score: 0.0010699083795771003
# Validation score: 0.0010246465681120753
# Threshold value: 0.008048248011618853
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 31.851851851851855%
# Epoch 9
# Train score: 0.0010612057521939278
# Validation score: 0.0010217088274657726
# Threshold value: 0.00795705639757216
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 28.580246913580247%
# Fold 4
# Epoch 0
# Train score: 0.001041013398207724
# Validation score: 0.0010163822444155812
# Threshold value: 0.007499447907321155
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 34.69135802469136%
# Epoch 1
# Train score: 0.001044525415636599
# Validation score: 0.001020536059513688
# Threshold value: 0.007357718306593597
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 36.23456790123456%
# Epoch 2
# Train score: 0.0011969076003879309
# Validation score: 0.001170642557553947
# Threshold value: 0.007996635744348168
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 38.2716049382716%
# Epoch 3
# Train score: 0.0010312206577509642
# Validation score: 0.0010058428160846233
# Threshold value: 0.007064028875902295
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 37.71604938271605%
# Epoch 4
# Train score: 0.0010185205610468984
# Validation score: 0.0010009859688580036
# Threshold value: 0.0071535579627379775
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 35.74074074074074%
# Epoch 5
# Train score: 0.0010080583160743117
# Validation score: 0.0009826789610087872
# Threshold value: 0.006792228203266859
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 37.592592592592595%
# Epoch 6
# Train score: 0.0009878817945718765
# Validation score: 0.0009699585498310626
# Threshold value: 0.0065781635930761695
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 37.34567901234568%
# Epoch 7
# Train score: 0.0009819020051509142
# Validation score: 0.000962555524893105
# Threshold value: 0.006794026237912476
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 37.22222222222222%
# Epoch 8
# Train score: 0.0009769302560016513
# Validation score: 0.0009503951296210289
# Threshold value: 0.006434846785850823
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 37.22222222222222%
# Epoch 9
# Train score: 0.0009773598285391927
# Validation score: 0.0009532618569210172
# Threshold value: 0.006502615986391902
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 35.49382716049383%
# Fold 5
# Epoch 0
# Train score: 0.0009783527348190546
# Validation score: 0.001002758857794106
# Threshold value: 0.006427567801438272
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 35.55555555555556%
# Epoch 1
# Train score: 0.0009742161491885781
# Validation score: 0.001006468664854765
# Threshold value: 0.006443769438192248
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 37.839506172839506%
# Epoch 2
# Train score: 0.0009899631841108203
# Validation score: 0.0010088366689160466
# Threshold value: 0.006661019753664732
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 35.24691358024691%
# Epoch 3
# Train score: 0.000910680799279362
# Validation score: 0.0009328964515589178
# Threshold value: 0.006027620052918792
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 37.46913580246913%
# Epoch 4
# Train score: 0.0009009093046188354
# Validation score: 0.0009261696832254529
# Threshold value: 0.005949546932242811
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 38.7037037037037%
# Epoch 5
# Train score: 0.0008910366450436413
# Validation score: 0.0009158910252153873
# Threshold value: 0.005784371867775917
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 40.06172839506173%
# Epoch 6
# Train score: 0.0009344900608994067
# Validation score: 0.0009561136830598116
# Threshold value: 0.005903226789087057
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 39.01234567901234%
# Epoch 7
# Train score: 0.0008696889271959662
# Validation score: 0.0008908627205528319
# Threshold value: 0.005770552670583129
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 41.7283950617284%
# Epoch 8
# Train score: 0.0008609901997260749
# Validation score: 0.0008876778883859515
# Threshold value: 0.005497443489730358
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 41.04938271604938%
# Epoch 9
# Train score: 0.0008590005454607308
# Validation score: 0.0008872724720276892
# Threshold value: 0.005385580123402178
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 43.02469135802469%
# Fold 6
# Epoch 0
# Train score: 0.0008591373916715384
# Validation score: 0.0008480746764689684
# Threshold value: 0.005379816284403205
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 39.07407407407407%
# Epoch 1
# Train score: 0.000853122619446367
# Validation score: 0.0008400823571719229
# Threshold value: 0.005303271114826202
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 40.67901234567901%
# Epoch 2
# Train score: 0.0008361603831872344
# Validation score: 0.0008161791483871639
# Threshold value: 0.004999118158593774
# Normal train ratio: 99.94579945799458%
# Normal validation ratio: 100.0%
# Abnormal ratio: 39.382716049382715%
# Epoch 3
# Train score: 0.0008816260378807783
# Validation score: 0.0008626285125501454
# Threshold value: 0.005187174305319786
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 38.45679012345679%
# Epoch 4
# Train score: 0.000818051805254072
# Validation score: 0.0008029204909689724
# Threshold value: 0.0049090811517089605
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 43.45679012345679%
# Epoch 5
# Train score: 0.0008318974287249148
# Validation score: 0.0008215222624130547
# Threshold value: 0.004938403144478798
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 40.864197530864196%
# Epoch 6
# Train score: 0.0008234808337874711
# Validation score: 0.0008118585683405399
# Threshold value: 0.004849170567467809
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 43.02469135802469%
# Epoch 7
# Train score: 0.0008386886911466718
# Validation score: 0.0008223275071941316
# Threshold value: 0.004935886827297509
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 41.79012345679013%
# Epoch 8
# Train score: 0.0008574211969971657
# Validation score: 0.000838921288959682
# Threshold value: 0.00508551683742553
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 40.80246913580247%
# Epoch 9
# Train score: 0.0008162675658240914
# Validation score: 0.0007983433897607028
# Threshold value: 0.004869597963988781
# Normal train ratio: 99.95934959349594%
# Normal validation ratio: 100.0%
# Abnormal ratio: 39.69135802469136%
# Fold 7
# Epoch 0
# Train score: 0.0008511015912517905
# Validation score: 0.0008507785387337208
# Threshold value: 0.00509192340541631
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 37.03703703703704%
# Epoch 1
# Train score: 0.0008067385642789304
# Validation score: 0.0008099094848148525
# Threshold value: 0.004968105931766331
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 39.25925925925926%
# Epoch 2
# Train score: 0.0008076298981904984
# Validation score: 0.0008133160881698132
# Threshold value: 0.005169391166418791
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 39.62962962962963%
# Epoch 3
# Train score: 0.0008256490691564977
# Validation score: 0.0008314574370160699
# Threshold value: 0.005197238177061081
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 39.382716049382715%
# Epoch 4
# Train score: 0.0007946443511173129
# Validation score: 0.0008003282709978521
# Threshold value: 0.004971020156517625
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 39.75308641975309%
# Epoch 5
# Train score: 0.0007937081390991807
# Validation score: 0.0008058676030486822
# Threshold value: 0.005075015942566097
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 40.0%
# Epoch 6
# Train score: 0.000806584779638797
# Validation score: 0.0008178361458703876
# Threshold value: 0.005136488005518913
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 38.641975308641975%
# Epoch 7
# Train score: 0.0007941354415379465
# Validation score: 0.0008019853848963976
# Threshold value: 0.00496584502980113
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 40.80246913580247%
# Epoch 8
# Train score: 0.0007867236854508519
# Validation score: 0.0007901650969870389
# Threshold value: 0.004799626534804702
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 40.74074074074074%
# Epoch 9
# Train score: 0.0009348575840704143
# Validation score: 0.0009489812655374408
# Threshold value: 0.0055467234924435616
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 37.28395061728395%
# Fold 8
# Epoch 0
# Train score: 0.0008283415227197111
# Validation score: 0.000844588503241539
# Threshold value: 0.005311040673404932
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 38.333333333333336%
# Epoch 1
# Train score: 0.0007933512679301202
# Validation score: 0.0008034773636609316
# Threshold value: 0.00499525316990912
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 40.925925925925924%
# Epoch 2
# Train score: 0.0007658626418560743
# Validation score: 0.0007724700262770057
# Threshold value: 0.0047725263284519315
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 39.876543209876544%
# Epoch 3
# Train score: 0.00081335857976228
# Validation score: 0.0008234747801907361
# Threshold value: 0.005091864382848144
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 42.96296296296296%
# Epoch 4
# Train score: 0.0007791139069013298
# Validation score: 0.0007822331972420216
# Threshold value: 0.0048896357184275985
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 40.617283950617285%
# Epoch 5
# Train score: 0.0007748089265078306
# Validation score: 0.0007789555238559842
# Threshold value: 0.004937996971420944
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 39.32098765432099%
# Epoch 6
# Train score: 0.0007480065105482936
# Validation score: 0.0007556081982329488
# Threshold value: 0.004805426229722798
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 39.75308641975309%
# Epoch 7
# Train score: 0.0007669515325687826
# Validation score: 0.0007751663797535002
# Threshold value: 0.004837045446038246
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 41.172839506172835%
# Epoch 8
# Train score: 0.0007380183087661862
# Validation score: 0.0007378292502835393
# Threshold value: 0.004695770679973066
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 41.11111111111111%
# Epoch 9
# Train score: 0.0008729067631065845
# Validation score: 0.0008719031466171145
# Threshold value: 0.005332055618055165
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 38.02469135802469%
# Fold 9
# Epoch 0
# Train score: 0.0007144087576307356
# Validation score: 0.0007203772547654808
# Threshold value: 0.004444613587111235
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 42.160493827160494%
# Epoch 1
# Train score: 0.0007047024555504322
# Validation score: 0.0007057482143864036
# Threshold value: 0.004482254735194147
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 41.2962962962963%
# Epoch 2
# Train score: 0.0007789817755110562
# Validation score: 0.000779857742600143
# Threshold value: 0.005039123469032347
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 41.54320987654321%
# Epoch 3
# Train score: 0.0007631620392203331
# Validation score: 0.0007646293961443007
# Threshold value: 0.004857489839196205
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 42.22222222222222%
# Epoch 4
# Train score: 0.0006531253457069397
# Validation score: 0.0006509083905257285
# Threshold value: 0.00416962947929278
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 44.75308641975309%
# Epoch 5
# Train score: 0.0006762584671378136
# Validation score: 0.0006697261705994606
# Threshold value: 0.004578095395117998
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 41.9753086419753%
# Epoch 6
# Train score: 0.0006184543017297983
# Validation score: 0.0006143272039480507
# Threshold value: 0.004037962236907333
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 45.308641975308646%
# Epoch 7
# Train score: 0.000602345506194979
# Validation score: 0.0005980574642308056
# Threshold value: 0.004050433402881026
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 48.02469135802469%
# Epoch 8
# Train score: 0.0005969128105789423
# Validation score: 0.0005973889492452145
# Threshold value: 0.003958035260438919
# Normal train ratio: 99.89159891598915%
# Normal validation ratio: 100.0%
# Abnormal ratio: 48.7037037037037%
# Epoch 9
# Train score: 0.0005864024278707802
# Validation score: 0.0005824672989547253
# Threshold value: 0.003780327911954373
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 56.7283950617284%
# Fold 10
# Epoch 0
# Train score: 0.0005386899574659765
# Validation score: 0.0005465667345561087
# Threshold value: 0.003607263439334929
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 53.95061728395062%
# Epoch 1
# Train score: 0.000528851174749434
# Validation score: 0.0005380131187848747
# Threshold value: 0.0034052322153002024
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 56.7283950617284%
# Epoch 2
# Train score: 0.0005310900742188096
# Validation score: 0.0005354993045330048
# Threshold value: 0.003378401743248105
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 58.08641975308642%
# Epoch 3
# Train score: 0.0005554907256737351
# Validation score: 0.0005627517821267247
# Threshold value: 0.00348784145899117
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 62.839506172839506%
# Epoch 4
# Train score: 0.0005255257710814476
# Validation score: 0.0005346034886315465
# Threshold value: 0.003477685619145632
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 56.04938271604938%
# Epoch 5
# Train score: 0.000544917827937752
# Validation score: 0.0005654789274558425
# Threshold value: 0.0038639623671770096
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 51.358024691358025%
# Epoch 6
# Train score: 0.0005191222298890352
# Validation score: 0.0005330985877662897
# Threshold value: 0.0034989643609151244
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 54.69135802469136%
# Epoch 7
# Train score: 0.0005024783895350993
# Validation score: 0.0005086668534204364
# Threshold value: 0.003081487608142197
# Normal train ratio: 99.95934959349594%
# Normal validation ratio: 100.0%
# Abnormal ratio: 60.802469135802475%
# Epoch 8
# Train score: 0.0005186727503314614
# Validation score: 0.0005250362446531653
# Threshold value: 0.0032718146103434265
# Normal train ratio: 99.83739837398375%
# Normal validation ratio: 100.0%
# Abnormal ratio: 57.839506172839506%
# Epoch 9
# Train score: 0.0004929287824779749
# Validation score: 0.0005050687468610704
# Threshold value: 0.0032140297698788345
# Normal train ratio: 100.0%
# Normal validation ratio: 100.0%
# Abnormal ratio: 57.160493827160494%

# %%
print(threshold)
# Out:
# 0.0032140297698788345

# %%
model = model.cpu()
model.eval()
# Out:
# DAE(
#   (encoded): Sequential(
#     (0): Linear(in_features=101, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=32, out_features=16, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=16, out_features=8, bias=True)
#     (9): ReLU()
#   )
#   (decoded): Sequential(
#     (0): Linear(in_features=8, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=128, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=101, bias=True)
#     (9): Sigmoid()
#   )
# )

# %%
# Test model on normal data
with torch.no_grad():
    output = model(train_data)
    assert output.shape == train_data.shape, "The predicted data shape is not right!"
    mse_per_sample = [mean_squared_error(train_data[i], output[i]) for i in range(train_data.shape[0])]

    normal_test_ratio = sum([score < threshold for score in mse_per_sample])/float(len(mse_per_sample))
    tp = len([score for score in mse_per_sample if score < threshold])
    fn = len([score for score in mse_per_sample if score >= threshold])
    print(f"Normal ratio: {normal_test_ratio * 100}%")
    print(f"tp: {tp}")
    print(f"fn: {fn}")
# Out:
# Normal ratio: 100.0%
# tp: 8200
# fn: 0

# %%
# Test model on normal data
with torch.no_grad():
    output = model(test_data)
    assert output.shape == test_data.shape, "The predicted data shape is not right!"
    mse_per_sample = [mean_squared_error(test_data[i], output[i]) for i in range(test_data.shape[0])]

    abnormal_test_ratio = sum([score > threshold for score in mse_per_sample])/float(len(mse_per_sample))
    tn = len([score for score in mse_per_sample if score >= threshold])
    fp = len([score for score in mse_per_sample if score < threshold])
    print(f"Abnormal ratio: {abnormal_test_ratio * 100}%")
    print(f"tn: {tn}")
    print(f"fp: {fp}")
# Out:
# Abnormal ratio: 57.160493827160494%
# tn: 926
# fp: 694

# %%
plt.rcParams.update({'font.size': 18})
conf_matrix = np.array([[tn, fp], [fn, tp]])
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size="xx-large")

plt.xlabel('Predictions')
plt.ylabel('Actuals')
# plt.title(DATASET_NAME, fontsize=26)
plt.show()

# %%
SKIP_PLOT = 2
with torch.no_grad():
    plt.title("Training curve")
    plt.plot(range(len(history['train_loss'])-SKIP_PLOT),history['train_loss'][SKIP_PLOT:],'r')
    plt.plot(range(len(history['val_loss'])-SKIP_PLOT),history['val_loss'][SKIP_PLOT:],'g')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.show()

# %%
model = model.cpu()
model.eval()
SKIP_PLOT = 2
with torch.no_grad():
    plt.title("Training curve")
    plt.plot(range(len(history['threshold']) - SKIP_PLOT),history['threshold'][SKIP_PLOT:],'r')
    plt.xlabel("Epoch")
    plt.ylabel("Threshold")
    plt.show()

# %%
model = model.cpu()
model.eval()
with torch.no_grad():
    plt.title("Training curve")
    plt.plot(range(len(history['abnormal_ratio'])),history['abnormal_ratio'],'r')
    plt.xlabel("Epoch")
    plt.ylabel("Threshold")
    plt.show()
